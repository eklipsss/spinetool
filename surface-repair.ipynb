# %% [markdown]
# # Confocal Surface Repair
#
# Восстановление поверхностей шипиков для mouse- и human-наборов (датасет с почты), без изменения исходных `.off` файлов.
# Выполнение z-коррекции.

# %%
pip install trimesh
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install manifold3d
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
script_path = project_root / "confocal_surface_repair" / "run_confocal_surface_repair.py"
assert script_path.exists(), script_path
processes = 8
project_attachment_to_surface = True
# datasets = ["Mouse_basal"]
datasets = ["Human_age_85_basal_OFF", "Human_age85_apical_OFF", "Human_age40_basal_OFF", "Human_age40_apical_OFF"]
command = [sys.executable, "-m", "confocal_surface_repair.run_confocal_surface_repair", "--project-root", str(project_root), "--processes", str(processes)]
if project_attachment_to_surface:
    command.append("--project-attachment-to-surface")
for dataset in datasets:
    command.extend(["--dataset", dataset])

print("Running:", " ".join(command))
result = subprocess.run(
    command,
    cwd=project_root,
    text=True,
    capture_output=True,
)

if result.stdout:
    print(result.stdout)
if result.stderr:
    print("STDERR:\n" + result.stderr)

print("Код завершения:", result.returncode)
if result.returncode != 0:
    raise subprocess.CalledProcessError(result.returncode, result.args, output=result.stdout, stderr=result.stderr)
# Out:
# Running: C:\Users\Student\.conda\envs\spine-analysis\python.exe -m confocal_surface_repair.run_confocal_surface_repair --project-root C:\Users\Student\Липс Екатерина\Spinetool - basic metric --processes 8 --project-attachment-to-surface --dataset Human_age_85_basal_OFF --dataset Human_age85_apical_OFF --dataset Human_age40_basal_OFF --dataset Human_age40_apical_OFF
# [Human_age_85_basal_OFF] start: total=1962 processes=8 mode=parallel
#
# [Human_age_85_basal_OFF] progress 1/1962 (  0.1%) | repaired=0 unchanged=1 skipped=0 missing=0 failed=0
# [Human_age_85_basal_OFF] progress 2/1962 (  0.1%) | repaired=0 unchanged=2 skipped=0 missing=0 failed=0
# [Human_age_85_basal_OFF] progress 3/1962 (  0.2%) | repaired=1 unchanged=2 skipped=0 missing=0 failed=0
# [Human_age_85_basal_OFF] progress 4/1962 (  0.2%) | repaired=1 unchanged=3 skipped=0 missing=0 failed=0
# [Human_age_85_basal_OFF] progress 5/1962 (  0.3%) | repaired=1 unchanged=4 skipped=0 missing=0 failed=0
# ...

# %%
from confocal_surface_repair.visualize_confocal_surface_repair import (
    debug_spine_repair,
    plot_repair_comparison,
    plot_repair_comparison_interactive,
)
from pathlib import Path
import subprocess
import sys

project_root = Path.cwd()
spine_id = "Mouse_basal/spine_10"
show_junction = False
show_projected_junction = True
# fig = plot_repair_comparison(project_root, spine_id, show_junction=show_junction, show_projected_junction=show_projected_junction)
# fig

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"
interactive_fig = plot_repair_comparison_interactive(project_root, spine_id, show_junction=show_junction, show_projected_junction=show_projected_junction)
interactive_fig.show()
# Out:
# Attachment point (last skeleton point): [22.388999938964844, 55.47200012207031, 4.746000080108643]
# Projected attachment point: [22.257200241088867, 55.570701599121094, 4.647719860076904]
#         <script>
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         </script>
#         <script type="module">import "https://cdn.plot.ly/plotly-3.4.0.min"</script>
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script>if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script>window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
debug_info = debug_spine_repair(project_root, spine_id)
debug_info
# Out:
# {'spine_id': 'Mouse_basal/spine_10',
#  'mesh_path': 'C:\\Users\\Student\\Липс Екатерина\\Spinetool - basic metric\\Mouse_basal\\spine_10.off',
#  'lookup_name': 'cel14_den1_1_109_R',
#  'components_before': 2,
#  'components_after_first_step': 1,
#  'attachment_distance_before': 0.19175991228782172,
#  'attachment_distance_after_first_step': 0.1917606413779729,
#  'attachment_point': [22.388999938964844,
#   55.47200012207031,
#   4.746000080108643],
#  'first_step_performed': True,
#  'first_step_error': None}

# %%
pip install plotly
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
