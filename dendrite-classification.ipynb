# %%
pip install lightgbm
# Out:
# ...
#   Using cached lightgbm-4.6.0-py3-none-win_amd64.whl (1.5 MB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tabulate
# Out:
# ...
#   Using cached tabulate-0.9.0-py3-none-any.whl (35 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Деление исходных данных (Wt, Ab) на две части: обучающую и тестовую

# %%
from dendrite_classification import classification

# classification('dendr_class/all_dendr_metrics.csv')
classification('dendr_class/with graph/base/all_dendr_metrics.csv')
# Out:
# Количество в y_train:
# Wt    24
# Ab    17
# Name: Type, dtype: int64
#
# Количество в y_test:
# Wt    8
# Ab    6
# Name: Type, dtype: int64
# +------------+-----------------+----------------+---------------+----------------------+---------------------+
# | model      |   mean_train_f1 |   mean_test_f1 |   std_test_f1 |   mean_roc_auc_train |   mean_roc_auc_test |
# |------------+-----------------+----------------+---------------+----------------------+---------------------|
# | RandForest |        0.927136 |       0.733533 |     0.02722   |             0.958965 |            0.816667 |
# | LightGBM   |        0.903001 |       0.730844 |     0.0371287 |             0.959912 |            0.81875  |
# | GBoost     |        0.850338 |       0.719247 |     0.0412191 |             0.951389 |            0.872222 |
# | LogReg     |        0.853659 |       0.652797 |     0.0831    |             0.902146 |            0.794444 |
# ...

# %% [markdown]
# # Обучение на всех исходных данных (Wt, Ab) + тест на 9009 (Wt+9009, Ab+9009)

# %%
from dendrite_classification import classification

classification('dendr_class/with graph/base/all_dendr_metrics.csv', 'dendr_class/with graph/9009/all_dendr_metrics.csv')
# Out:
# +------------+-----------------+----------------+---------------+----------------------+---------------------+
# | model      |   mean_train_f1 |   mean_test_f1 |   std_test_f1 |   mean_roc_auc_train |   mean_roc_auc_test |
# |------------+-----------------+----------------+---------------+----------------------+---------------------|
# | RandForest |        0.945745 |       0.85372  |     0.0229337 |             0.975349 |            0.859361 |
# | LogReg     |        0.864577 |       0.817104 |     0.0943072 |             0.932588 |            0.885985 |
# | GBoost     |        0.963463 |       0.816625 |     0.0236648 |             0.974699 |            0.876082 |
# | LightGBM   |        0.928218 |       0.763578 |     0.0936873 |             0.981554 |            0.850595 |
# | LinSVM     |        0.835565 |       0.726197 |     0.158953  |             0.642538 |            0.651136 |
# ...

# %% [markdown]
# # Обучение на всех исходных данных + тест на Wt_old

# %%
from dendrite_classification import classification

classification('dendr_class/with graph/base/all_dendr_metrics.csv', 'dendr_class/with graph/wt_old_st/all_dendr_metrics.csv')
# Out:
# +------------+-----------------+----------------+---------------+----------------------+---------------------+
# | model      |   mean_train_f1 |   mean_test_f1 |   std_test_f1 |   mean_roc_auc_train |   mean_roc_auc_test |
# |------------+-----------------+----------------+---------------+----------------------+---------------------|
# | RandForest |        0.945745 |       0.85372  |     0.0229337 |             0.975349 |            0.859361 |
# | LogReg     |        0.864577 |       0.817104 |     0.0943072 |             0.932588 |            0.885985 |
# | GBoost     |        0.963463 |       0.816625 |     0.0236648 |             0.974699 |            0.876082 |
# | LightGBM   |        0.928218 |       0.763578 |     0.0936873 |             0.981554 |            0.850595 |
# | LinSVM     |        0.835565 |       0.726197 |     0.158953  |             0.642538 |            0.651136 |
# ...

# %% [markdown]
# # Обучение на части исходных данных (убрали 5 штук Ab) + тест на Wt_old + Ab из исходных

# %%
from dendrite_classification import classification

classification('metrics/wt_old_st_ab/part_of_original.csv', 'metrics/wt_old_st_ab/old_wt_ab.csv')
