# %% [markdown]
# # Utilities

# %% [markdown]
# Set dataset path and scale applied to spines during visualization.

# %%
pip install icosphere
# Out:
# Requirement already satisfied: icosphere in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge opencv
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# done
# done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
pip install shapely
# Out:
# Requirement already satisfied: shapely in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (2.0.7)
# Requirement already satisfied: numpy<3,>=1.14 in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (from shapely) (1.21.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tblib
# Out:
# Requirement already satisfied: tblib in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (3.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install tqdm
# Out:
# Requirement already satisfied: tqdm in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (4.67.1)
# Requirement already satisfied: colorama in c:\users\student\.conda\envs\spine-analysis\lib\site-packages (from tqdm) (0.4.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge umap-learn
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - conda-forge
#  - defaults
# Platform: win-64
# done
# done
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#     current version: 25.7.0
#     latest version: 26.1.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
conda install itertools
# Out:
# 3 channel Terms of Service accepted
# Channels:
#  - defaults
# Platform: win-64
# done
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - itertools
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
# conda update -n base -c defaults conda
# Out:
# 3 channel Terms of Service accepted
#
# Note: you may need to restart the kernel to use updated packages.
# EnvironmentNotWritableError: The current user does not have write permissions to the target environment.
#   environment location: C:\ProgramData\anaconda3

# %%
conda install pickle
# Out:
# 3 channel Terms of Service accepted
# done
# Channels:
#  - defaults
# Platform: win-64
# done
# failed
#
# Note: you may need to restart the kernel to use updated packages.
# PackagesNotFoundError: The following packages are not available from current channels:
#
#   - pickle
#
# Current channels:
#
#   - defaults
#
# To search for alternate channels that may provide the conda package you're
# looking for, navigate to
#
#     https://anaconda.org
#
# and use the search bar at the top of the page.

# %%
import plotly.io as pio
pio.renderers.default = "notebook_connected"

# %%
from notebook_widgets import SpineMeshDataset

import pickle

# Открытие файла в режиме чтения бинарных данных ('rb')
with open(r'Human_age_85_basal_OFF\attachment_centers.pkl', 'rb') as f:
    data = pickle.load(f)

print(data)

if "spine_0" in data:
    print("spine_0:", data["spine_0"])
else:
    print("spine_0 not found")

# set dataset path and scale applied to spines during visualization
dataset_path = "Human_age_85_basal_OFF\z-corr"
scale = (1, 1, 1)

# load and scale spine mesh dataset
spine_dataset = SpineMeshDataset().load(dataset_path, load_attachment_centers=True)
spine_dataset.orient_spines()
# scaled_spine_dataset = SpineMeshDataset().load(dataset_path)
# scaled_spine_dataset.apply_scale(scale)
# Out:
# spine_0       [64.57349700276045, 88.1308930996235, -28.3720...
# spine_1       [32.9057134833628, 59.899790352446395, -23.672...
# spine_2       [29.905631235633845, 57.58050810947759, -23.48...
# spine_3       [28.298418606461098, 57.363850682972576, -23.1...
# spine_4       [29.301826787371578, 58.155444373360076, -22.7...
#                                     ...
# spine_1717    [-4.0628585264542645, 21.561731754394696, -0.0...
# spine_1718    [-4.109633159715989, 23.147474212129993, -0.52...
# spine_1719    [-2.379170673478069, 27.369980444922724, -0.48...
# spine_1720    [-0.8967063034358962, 29.18762017097173, 0.427...
# spine_1721    [0.17782347532299284, 30.14651307806653, 0.428...
# Name: attachment_center, Length: 1874, dtype: object
# spine_0: [64.57349700276045, 88.1308930996235, -28.37207210763375]
# spine_name Human_age_85_basal_OFF\z-corr\spine_0.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_100.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1000.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1001.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1003.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1004.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1005.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1006.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1007.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1008.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1009.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_101.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1010.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1011.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1012.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1013.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1014.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1015.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1016.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1017.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1018.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1019.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_102.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1021.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1022.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1023.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1024.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1025.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1026.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1027.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1028.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1029.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_103.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1031.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1032.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1033.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1034.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1035.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1036.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1038.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1039.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_104.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1040.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1041.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1043.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1044.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1045.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1046.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1047.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1048.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1049.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1050.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1051.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1052.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1053.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1054.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1055.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1056.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1057.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1058.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1059.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_106.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1061.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1062.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1063.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1064.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1065.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1066.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1067.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1068.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1069.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_107.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1070.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1071.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1072.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1073.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1074.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1075.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1076.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1078.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1079.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_108.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1080.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1081.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1082.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1083.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1084.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1085.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1087.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_109.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1091.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1096.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1098.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1099.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_11.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_110.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1101.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1102.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1103.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1104.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1105.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1106.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1107.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1108.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1109.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_111.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1110.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1111.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1112.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1113.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1114.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1115.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1116.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1117.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1118.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1119.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_112.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1120.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1121.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1122.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1123.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1124.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1125.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1126.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1127.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1128.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1129.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_113.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1130.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1131.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1132.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1133.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1134.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1135.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1136.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1137.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1138.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1139.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_114.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1140.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1141.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1142.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1143.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1144.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1145.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1146.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1147.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1148.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1149.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_115.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1150.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1151.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1152.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1153.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1154.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1155.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1156.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1157.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1158.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1159.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_116.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1161.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1162.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1163.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1164.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1165.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1166.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1167.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1168.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1169.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_117.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1170.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1171.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1172.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1173.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1174.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1175.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1176.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1177.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1178.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1179.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_118.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1181.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1182.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1183.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1184.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1185.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1186.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1187.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1188.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1189.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_119.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1190.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1191.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1192.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1193.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1194.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1195.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1196.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1197.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1198.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1199.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_12.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_120.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1200.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1201.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1202.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1203.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1204.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1206.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1207.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1208.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1209.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_121.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1210.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1211.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1212.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1213.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1214.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1215.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1216.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1217.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1218.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1219.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_122.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1220.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1221.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1222.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1223.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1224.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1225.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1226.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1227.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1228.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1229.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_123.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1230.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1231.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1232.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1233.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1234.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1235.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1236.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1237.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1238.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1239.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_124.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1240.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1241.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1242.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1243.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1244.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1245.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1246.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1247.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1248.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1249.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_125.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1250.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1251.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1252.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1253.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1255.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1256.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1257.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1258.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1259.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_126.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1260.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1261.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1262.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1263.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1264.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1265.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1266.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1267.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1268.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1269.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_127.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1270.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1271.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1272.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1273.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1274.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1275.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1276.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1277.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1278.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1279.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_128.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1280.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1281.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1282.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1283.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1284.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1285.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1286.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1287.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1288.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1289.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_129.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1290.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1291.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1292.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1293.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1295.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1296.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1297.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1298.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1299.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_13.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_130.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1300.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1301.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1302.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1303.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1304.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1305.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1306.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1307.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1308.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1309.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_131.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1310.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1311.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1312.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1313.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1314.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1315.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1316.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1317.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1319.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_132.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1320.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1321.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1322.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1323.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1324.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1325.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1326.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1327.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1328.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1329.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_133.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1330.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1331.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1332.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1333.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1334.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1335.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1336.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1337.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1338.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_134.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1340.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1341.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1342.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1344.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1345.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1346.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1347.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1348.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1349.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_135.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1350.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1351.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1352.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1353.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1354.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1355.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1356.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1357.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1358.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1359.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_136.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1360.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1361.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1362.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1363.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1364.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1365.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1366.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1367.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1368.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1369.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_137.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1370.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1371.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1372.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1373.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1374.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1375.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1376.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1377.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1378.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1379.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_138.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1380.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1381.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1382.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1383.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1384.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1385.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1386.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1387.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1388.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1389.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_139.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1390.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1391.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1392.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1393.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1394.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1395.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1397.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1399.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_14.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_140.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1400.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1401.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1402.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1403.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1404.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1405.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1406.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1407.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1409.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1410.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1411.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1412.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1413.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1414.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1415.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1416.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1417.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1418.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1419.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_142.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1420.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1421.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1422.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1423.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1424.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1425.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1426.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1427.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1428.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1429.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_143.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1430.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1431.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1432.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1433.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1434.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1435.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1436.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1437.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1438.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1439.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_144.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1440.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1441.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1442.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1443.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1444.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1445.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1446.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1447.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1448.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1449.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_145.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1450.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1451.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1452.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1453.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1454.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1455.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1456.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1457.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1458.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1459.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_146.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1460.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1461.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1462.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1463.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1465.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1467.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1468.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1469.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1470.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1471.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1472.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1473.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1474.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1475.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1476.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1477.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1478.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1479.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_148.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1480.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1481.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1482.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1483.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1484.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1485.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1486.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1487.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1488.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1489.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_149.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1490.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1491.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1492.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1493.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1494.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1495.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1496.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1497.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1498.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1499.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_15.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1500.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1501.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1502.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1503.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1504.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1505.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1506.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1507.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1508.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1509.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_151.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1510.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1511.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1512.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1513.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1514.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1515.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1516.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1517.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1518.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1519.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_152.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1520.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1521.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1522.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1523.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1524.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1525.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1526.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1527.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1528.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1529.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_153.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1530.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1531.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1532.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1533.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1534.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1536.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1537.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1538.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1539.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_154.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1541.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1542.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1543.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1544.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1545.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1546.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1547.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1548.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1549.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1550.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1551.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1552.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1553.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1554.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1555.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1556.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1557.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1558.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1559.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_156.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1560.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1561.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1562.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1563.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1564.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1565.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1566.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1567.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1568.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1569.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_157.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1570.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1571.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1572.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1573.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1574.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1575.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1576.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1577.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1578.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1579.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_158.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1580.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1581.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1582.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1583.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1584.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1585.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1586.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1587.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1588.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1589.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_159.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1590.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1591.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1592.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1593.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1594.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1595.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1596.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1597.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1598.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1599.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_16.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_160.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1600.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1601.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1602.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1603.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1604.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1607.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1608.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1609.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_161.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1610.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1611.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1612.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1613.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1614.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1615.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1616.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1617.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1618.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1619.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_162.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1620.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1621.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1622.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1623.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1624.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1625.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1626.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1627.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1628.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1629.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_163.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1630.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1631.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1632.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1633.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1634.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1635.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1636.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1637.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1638.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_164.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1640.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1641.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1642.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1643.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1644.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1645.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1646.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1647.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1648.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1649.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_165.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1650.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1651.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1652.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1653.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1654.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1656.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1657.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1658.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1659.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_166.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1660.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1661.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1662.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1663.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1664.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1666.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1669.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_167.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1670.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1671.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1672.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1673.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1674.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1675.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1676.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1677.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1678.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1679.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_168.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1680.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1681.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1682.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1683.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1684.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1685.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1686.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1687.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1688.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1689.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1690.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1691.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1692.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1693.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1694.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1695.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1696.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1697.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1698.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1699.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_17.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_170.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1700.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1701.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1702.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1703.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1704.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1705.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1706.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1707.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1708.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1709.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_171.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1710.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1711.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1712.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1713.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1714.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1715.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1716.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1717.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1718.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1719.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_172.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1720.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1721.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1722.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1723.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1724.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1725.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1726.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1727.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1728.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1729.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_173.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1730.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1731.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1732.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1733.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1734.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1735.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1736.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1737.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1738.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1739.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_174.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1740.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1741.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1742.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1743.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1744.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1745.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1746.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1747.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1748.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1749.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_175.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1750.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1751.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1752.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1753.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1754.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1755.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1756.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1757.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1758.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1759.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_176.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1760.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1761.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1762.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1763.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1764.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1765.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1766.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1767.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1768.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1769.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_177.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1770.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1771.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1773.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1774.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1775.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1776.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1777.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1778.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1779.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_178.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1780.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1781.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1782.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1783.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1784.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1785.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1786.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1787.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1788.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1789.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_179.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1790.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1791.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1792.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1793.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1794.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1795.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1796.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1797.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1798.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_1799.off
# spine_name Human_age_85_basal_OFF\z-corr\spine_18.off
# ...
# rotation_axis_before_normalization: [0.9191396931043542, 0.0, -0.24738409634500078]
# rotation_axis_length: 0.9518490776191355
# rotation_axis_normalized: [0.9656359550228304, 0.0, -0.2598984462576607]
# rotation_angle_t: 1.882380603601185
# pca_component: [0.9885459914763831, 0.15091992160074405]
# second_rotation_angle_t: 1.4192975395010625
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [22.978781096683804, 135.26166109284603, 31.613574152536692]
# junction_triangles_count: 12
# valid_triangle_count: 12
# invalid_triangle_count: 0
# total_junction_area: 0.0020744913365531394
# mean_norm_before_normalization: [0.0020333039999996024, -0.00023217600000006848, 0.0001990499999997998]
# mean_norm_length: 0.0020561740572943563
# mean_norm_normalized: [0.9888773728986505, -0.11291651072846445, 0.09680600691058341]
# rotation_axis_before_normalization: [0.09680600691058341, 0.0, -0.9888773728986505]
# rotation_axis_length: 0.9936044794609717
# rotation_axis_normalized: [0.09742911682835856, 0.0, -0.9952424665346863]
# rotation_angle_t: 1.457638478607434
# pca_component: [-0.38663333093796853, -0.9222335210822754]
# second_rotation_angle_t: -2.7446144270814425
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [7.622652645474899, 104.36547999781072, 30.198294322909494]
# junction_triangles_count: 13
# valid_triangle_count: 13
# invalid_triangle_count: 0
# total_junction_area: 0.0015620822611495614
# mean_norm_before_normalization: [0.0009853524825302884, 0.0011743210575332341, -0.0003002521443704609]
# mean_norm_length: 0.0015620822037247706
# mean_norm_normalized: [0.6307942566535388, 0.7517664913748306, -0.19221276809537452]
# rotation_axis_before_normalization: [-0.19221276809537452, -0.0, -0.6307942566535388]
# rotation_axis_length: 0.6594294067191551
# rotation_axis_normalized: [-0.29148346454806523, -0.0, -0.9565758672970257]
# rotation_angle_t: 2.4215331489686536
# pca_component: [-0.9999999341280724, -0.00036296535781691735]
# second_rotation_angle_t: -1.5711592921606832
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.61836035779797, 136.3995016835604, 31.0843669424369]
# junction_triangles_count: 48
# valid_triangle_count: 48
# invalid_triangle_count: 0
# total_junction_area: 0.17433363305195482
# mean_norm_before_normalization: [0.003659838000000219, -0.003799849200000108, 0.17397069999999545]
# mean_norm_length: 0.17405067574306457
# mean_norm_normalized: [0.021027427698142982, -0.02183185548563733, 0.9995405031165339]
# rotation_axis_before_normalization: [0.9995405031165339, 0.0, -0.021027427698142982]
# rotation_axis_length: 0.9997616566392483
# rotation_axis_normalized: [0.9997787937542455, 0.0, -0.021032440640730104]
# rotation_angle_t: 1.5489627366512781
# pca_component: [-0.9947725333182266, 0.10211565480198453]
# second_rotation_angle_t: -1.4685023637025012
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.187000274658203, 136.9427830182443, 31.491292398297333]
# junction_triangles_count: 13
# valid_triangle_count: 13
# invalid_triangle_count: 0
# total_junction_area: 0.001562175030414008
# mean_norm_before_normalization: [0.0, -0.0015329825055232504, 0.0003005918551934883]
# mean_norm_length: 0.0015621750304140075
# mean_norm_normalized: [0.0, -0.9813128975163427, 0.19241880669019876]
# rotation_axis_before_normalization: [0.19241880669019876, 0.0, 0.0]
# rotation_axis_length: 0.19241880669019876
# rotation_axis_normalized: [1.0, 0.0, 0.0]
# rotation_angle_t: 0.19362642158332838
# pca_component: [-0.829311397915164, -0.5587867261200793]
# second_rotation_angle_t: -2.1637184149703828
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.150182957063464, 137.5505290972876, 31.24065458943156]
# junction_triangles_count: 13
# valid_triangle_count: 13
# invalid_triangle_count: 0
# total_junction_area: 0.002855569238941904
# mean_norm_before_normalization: [0.0024154619999998198, -0.0009627324000000271, 0.0009978499999999258]
# mean_norm_length: 0.002785141822233258
# mean_norm_normalized: [0.8672671462248872, -0.34566728068018554, 0.35827618975604003]
# rotation_axis_before_normalization: [0.35827618975604003, 0.0, -0.8672671462248872]
# rotation_axis_length: 0.9383571447307075
# rotation_axis_normalized: [0.3818121828857169, 0.0, -0.9242399347572273]
# rotation_angle_t: 1.2178465188602001
# pca_component: [-0.08807859881373466, -0.9961135278827454]
# second_rotation_angle_t: -3.0533997720875785
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.914640875679655, 137.8285597670426, 31.762737045191656]
# junction_triangles_count: 19
# valid_triangle_count: 19
# invalid_triangle_count: 0
# total_junction_area: 0.00937697595077949
# mean_norm_before_normalization: [-0.0007212239999997634, -0.0002525838000000851, -0.009293399999998639]
# mean_norm_length: 0.009324765208527925
# mean_norm_normalized: [-0.07734500374767303, -0.027087416610670864, -0.9966363540713495]
# rotation_axis_before_normalization: [-0.9966363540713495, 0.0, 0.07734500374767303]
# rotation_axis_length: 0.999633068611358
# rotation_axis_normalized: [-0.9970021854677423, 0.0, 0.0773733944747516]
# rotation_angle_t: 1.5437055966234186
# pca_component: [-0.047196893945150815, 0.9988856056635966]
# second_rotation_angle_t: -0.0472144337476719
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [24.220351822470565, 138.20587702281543, 31.02215568772477]
# junction_triangles_count: 12
# valid_triangle_count: 12
# invalid_triangle_count: 0
# total_junction_area: 0.0035075830219590738
# mean_norm_before_normalization: [-0.0033241320000008193, 0.000612544800000006, 0.0008794500000001735]
# mean_norm_length: 0.003492634677136559
# mean_norm_normalized: [-0.9517548519349046, 0.17538186974144163, 0.25180131370658887]
# rotation_axis_before_normalization: [0.25180131370658887, 0.0, 0.9517548519349046]
# rotation_axis_length: 0.9845004823594533
# rotation_axis_normalized: [0.25576555646079724, 0.0, 0.9667388376021203]
# rotation_angle_t: 1.747089963289276
# pca_component: [-0.20817822746704792, 0.9780909086627267]
# second_rotation_angle_t: -0.20971200937105522
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.844338971408988, 139.6531942116665, 30.035141834465513]
# junction_triangles_count: 14
# valid_triangle_count: 14
# invalid_triangle_count: 0
# total_junction_area: 0.0031073262334709822
# mean_norm_before_normalization: [0.00010722599999991746, 0.0005931155999999893, -0.003018850000000203]
# mean_norm_length: 0.0030784312323877813
# mean_norm_normalized: [0.03483137738202706, 0.19266813361295712, -0.9806455860502156]
# rotation_axis_before_normalization: [-0.9806455860502156, -0.0, -0.03483137738202706]
# rotation_axis_length: 0.9812639758444717
# rotation_axis_normalized: [-0.9993698028160833, -0.0, -0.035496439530505866]
# rotation_angle_t: 1.7646768295556816
# pca_component: [0.566408826636146, 0.824124408756751]
# second_rotation_angle_t: 0.6021417343137446
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [29.860613835934835, 57.03607888913683, -22.875949780368668]
# junction_triangles_count: 12
# valid_triangle_count: 12
# invalid_triangle_count: 0
# total_junction_area: 0.013960134544088041
# mean_norm_before_normalization: [-0.004284693000000222, 0.011271376199999891, -0.006921719999999916]
# mean_norm_length: 0.013903694591890808
# mean_norm_normalized: [-0.3081693841649274, 0.810674898352112, -0.4978331445828032]
# rotation_axis_before_normalization: [-0.4978331445828032, 0.0, 0.3081693841649274]
# rotation_axis_length: 0.5854965492484074
# rotation_axis_normalized: [-0.8502751130162315, 0.0, 0.5263385148221958]
# rotation_angle_t: 2.5161002177989693
# pca_component: [-0.2714175352942688, -0.9624616987365182]
# second_rotation_angle_t: -2.866727104774321
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.723943285500848, 140.371554298855, 31.493153254755725]
# junction_triangles_count: 28
# valid_triangle_count: 28
# invalid_triangle_count: 0
# total_junction_area: 0.1026814541796135
# mean_norm_before_normalization: [-0.0032031300000001477, -0.0011788014000004001, -0.10244299999999981]
# mean_norm_length: 0.10249984323664844
# mean_norm_normalized: [-0.03125009657434169, -0.01150051905229572, -0.9994454309894173]
# rotation_axis_before_normalization: [-0.9994454309894173, 0.0, 0.03125009657434169]
# rotation_axis_length: 0.9999338668439667
# rotation_axis_normalized: [-0.9995115318415096, 0.0, 0.03125216337853878]
# rotation_angle_t: 1.5592955542140163
# pca_component: [0.9959511053241681, -0.08989658393714278]
# second_rotation_angle_t: 1.6608144348368454
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.299707229430876, 142.0101206929106, 31.454572473082052]
# junction_triangles_count: 14
# valid_triangle_count: 14
# invalid_triangle_count: 0
# total_junction_area: 0.041630741217255636
# mean_norm_before_normalization: [-0.0020040719999994917, -0.0019036794000004314, -0.04143294999999618]
# mean_norm_length: 0.04152504841106572
# mean_norm_normalized: [-0.04826176191682514, -0.04584412235129708, -0.9977820998507254]
# rotation_axis_before_normalization: [-0.9977820998507254, 0.0, 0.04826176191682514]
# rotation_axis_length: 0.9989486055077305
# rotation_axis_normalized: [-0.998832266594524, 0.0, 0.0483125574736604]
# rotation_angle_t: 1.5249361309309744
# pca_component: [0.5256645367523918, 0.8506919505913366]
# second_rotation_angle_t: 0.5534960967522096
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [24.01494838771274, 142.135, 31.131124281619652]
# junction_triangles_count: 15
# valid_triangle_count: 15
# invalid_triangle_count: 0
# total_junction_area: 0.00495977985831387
# mean_norm_before_normalization: [-0.004794299999999541, 0.0005150837999998045, -0.00037069999999998163]
# mean_norm_length: 0.004836118516022723
# mean_norm_normalized: [-0.9913528760958542, 0.10650768757904946, -0.07665238119616005]
# rotation_axis_before_normalization: [-0.07665238119616005, 0.0, 0.9913528760958542]
# rotation_axis_length: 0.9943118788823573
# rotation_axis_normalized: [-0.07709088347845157, 0.0, 0.9970240697618648]
# rotation_angle_t: 1.677506417842717
# pca_component: [-0.9988499546862446, -0.04794546926756905]
# second_rotation_angle_t: -1.6187601843424348
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.82152355699481, 142.31170828917828, 31.187145805358085]
# junction_triangles_count: 21
# valid_triangle_count: 21
# invalid_triangle_count: 0
# total_junction_area: 0.015954850535781735
# mean_norm_before_normalization: [-0.010023510000000617, -0.011970432600000212, -0.0023910499999990537]
# mean_norm_length: 0.01579490833951738
# mean_norm_normalized: [-0.6346038726241123, -0.7578665442490294, -0.15138106208675303]
# rotation_axis_before_normalization: [-0.15138106208675303, 0.0, 0.6346038726241123]
# rotation_axis_length: 0.6524096114467
# rotation_axis_normalized: [-0.23203377054956284, 0.0, 0.9727077306799575]
# rotation_angle_t: 0.7107595694550912
# pca_component: [-0.31571451178216964, -0.9488542285568138]
# second_rotation_angle_t: -2.8203830679117714
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [8.254224977650212, 103.97491101066399, 30.59784874214246]
# junction_triangles_count: 15
# valid_triangle_count: 15
# invalid_triangle_count: 0
# total_junction_area: 0.0032740184344654537
# mean_norm_before_normalization: [-0.0009224460000003014, 0.003049493159999903, -0.0006342650000000458]
# mean_norm_length: 0.0032484776813190216
# mean_norm_normalized: [-0.28396254815140015, 0.9387453013873495, -0.19524991772223196]
# rotation_axis_before_normalization: [-0.19524991772223196, 0.0, 0.28396254815140015]
# rotation_axis_length: 0.34461175128421634
# rotation_axis_normalized: [-0.5665793954925259, 0.0, 0.8240071532476669]
# rotation_angle_t: 2.789767482498332
# pca_component: [-0.4744200833213633, -0.8802985769279368]
# second_rotation_angle_t: -2.6472875116145707
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [22.600071523954863, 143.3605549197551, 30.54803013010594]
# junction_triangles_count: 17
# valid_triangle_count: 17
# invalid_triangle_count: 0
# total_junction_area: 0.060086807530393124
# mean_norm_before_normalization: [0.018965268000000184, 0.016971490199999814, 0.05442134999999955]
# mean_norm_length: 0.06007825068810652
# mean_norm_normalized: [0.315676102129829, 0.28248975304068896, 0.905841121815039]
# rotation_axis_before_normalization: [0.905841121815039, 0.0, -0.315676102129829]
# rotation_axis_length: 0.9592703161398306
# rotation_axis_normalized: [0.9443022540926791, 0.0, -0.3290794021440497]
# rotation_angle_t: 1.8571849133138385
# pca_component: [0.03296420036537242, -0.9994565330689832]
# second_rotation_angle_t: 3.108622480275025
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [23.30333321851903, 143.45122002460334, 30.73397709483564]
# junction_triangles_count: 18
# valid_triangle_count: 18
# invalid_triangle_count: 0
# total_junction_area: 0.016709324718262593
# mean_norm_before_normalization: [-0.016554406014620326, -0.0018138919840566814, -1.5522804460488253e-05]
# mean_norm_length: 0.016653492233888394
# mean_norm_normalized: [-0.9940501236691704, -0.10891961629318628, -0.0009321050649605318]
# rotation_axis_before_normalization: [-0.0009321050649605318, 0.0, 0.9940501236691704]
# rotation_axis_length: 0.9940505606791564
# rotation_axis_normalized: [-0.0009376837575783849, 0.0, 0.9999995603744887]
# rotation_angle_t: 1.461660191598225
# pca_component: [0.7088875457481616, 0.7053215206437049]
# second_rotation_angle_t: 0.7879197266028248
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [21.504660593281695, 144.6188500070217, 30.836909057494815]
# junction_triangles_count: 22
# valid_triangle_count: 22
# invalid_triangle_count: 0
# total_junction_area: 0.018910316299242107
# mean_norm_before_normalization: [0.018628024583449587, -0.00036429228384804446, 0.0012810404878109694]
# mean_norm_length: 0.01867557424769274
# mean_norm_normalized: [0.9974539115310455, -0.019506349792325697, 0.06859443628456215]
# rotation_axis_before_normalization: [0.06859443628456215, 0.0, -0.9974539115310455]
# rotation_axis_length: 0.9998097330581351
# rotation_axis_normalized: [0.06860749002187763, 0.0, -0.9976437301526523]
# rotation_angle_t: 1.5512887397705684
# pca_component: [0.9986511068372327, 0.051922700360923384]
# second_rotation_angle_t: 1.5188502677716482
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [22.037242294711362, 147.5345891284224, 30.82176107437281]
# junction_triangles_count: 21
# valid_triangle_count: 21
# invalid_triangle_count: 0
# total_junction_area: 0.0311728488596118
# mean_norm_before_normalization: [-0.025070471999998963, -0.018284603400000154, -0.001395199999999942]
# mean_norm_length: 0.031061259968617323
# mean_norm_normalized: [-0.807129911192555, -0.5886626433851674, -0.0449176885100469]
# rotation_axis_before_normalization: [-0.0449176885100469, 0.0, 0.807129911192555]
# rotation_axis_length: 0.8083788049440604
# rotation_axis_normalized: [-0.05556514870915646, 0.0, 0.9984550637103952]
# rotation_angle_t: 0.941392853223743
# pca_component: [-0.851605246758722, 0.5241836545458247]
# second_rotation_angle_t: -1.0190400929001302
# ##### ORIENT DEBUG END #####
# ##### ORIENT DEBUG START #####
# attachment_center: [21.897606446197642, 148.52935194923452, 30.27364874886125]
# junction_triangles_count: 15
# valid_triangle_count: 15
# invalid_triangle_count: 0
# total_junction_area: 0.0023884102278371976
# mean_norm_before_normalization: [-0.0018535440000000266, -0.00022200780000007286, 0.0013684999999998549]
# mean_norm_length: 0.0023146716987937133
# mean_norm_normalized: [-0.8007805171532522, -0.0959132995473059, 0.591228553368085]
# rotation_axis_before_normalization: [0.591228553368085, 0.0, 0.8007805171532522]
# rotation_axis_length: 0.9953896920151165
# rotation_axis_normalized: [0.5939669238197278, 0.0, 0.8044894613406255]
# rotation_angle_t: 1.4747353582749771
# pca_component: [0.02445451137037767, -0.9997009437194887]
# second_rotation_angle_t: 3.1171357041693635
# ##### ORIENT DEBUG END #####

# %% [markdown]
# ### View Dendrite Skeleton

# %%
from notebook_widgets import view_skeleton_widget


display(view_skeleton_widget(scaled_spine_dataset))

# %% [markdown]
# ### View Dendrite segmentation

# %%
from notebook_widgets import dendrite_segmentation_view_widget

display(dendrite_segmentation_view_widget(scaled_spine_dataset))

# %% [markdown]
# ### View Chords
# Set `num_of_chords` and `num_of_bins`. Histograms can be exported to `dataset_path/chords_%num_of_chords%_chords_%num_of_bins%_bins.csv` file. Histograms are only exported for meshes that were viewed! Otherwise it would take too much time to calculate. Use `Calculate Metrics` cell to calculate metrics for the entire dataset.

# %%
from notebook_widgets import spine_chords_widget


num_of_chords = 30000
num_of_bins = 100

display(spine_chords_widget(spine_dataset, scaled_spine_dataset, dataset_path, num_of_chords, num_of_bins))

# %% [markdown]
# ### Calculate Metrics
# Metrics for the dataset will be saved to `dataset_path/metrics.csv`. Chords histograms will be saved separately to `dataset_path/chords.csv`.

# %%
from spine_analysis.shape_metric.io_metric import SpineMetricDataset
import time
import itertools
import os
from pathlib import Path

t0 = time.perf_counter()

num_of_chords = 30000
num_of_bins = 100

# metric_names = [
#     "OldChordDistribution", "OpenAngle", "CVD", "AverageDistance",
#     "LengthVolumeRatio", "LengthAreaRatio", "JunctionArea",
#     "Length", "Area", "Volume", "ConvexHullVolume", "ConvexHullRatio"
# ]

metric_names = [ "OpenAngle", "CVD", "AverageDistance",
    "LengthVolumeRatio", "LengthAreaRatio", "JunctionArea",
    "Length", "Area", "Volume", "ConvexHullVolume", "ConvexHullRatio"
]

# metric_params = [
#     {"num_of_chords": num_of_chords, "num_of_bins": num_of_bins},
#     {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}
# ]

metric_params = [
    {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}
]


out_metrics_path = Path(dataset_path) / "metrics.csv"
# out_chords_path = Path(dataset_path) / "chords.csv"

tmp_metrics_path = out_metrics_path.with_suffix(".tmp.csv")
# tmp_chords_path = out_chords_path.with_suffix(".tmp.csv")

batch_size = 10
start_batch = 0

out_metrics_path.parent.mkdir(parents=True, exist_ok=True)

def iter_batches_from_dict(d: dict, batch_size: int, start_batch: int = 0):
    start_item = start_batch * batch_size
    it = itertools.islice(d.items(), start_item, None)
    while True:
        chunk = list(itertools.islice(it, batch_size))
        if not chunk:
            break
        yield dict(chunk)

def append_file(src_path: Path, dst_path: Path, retries: int = 5, delay: float = 1.0):
    last_err = None
    for _ in range(retries):
        try:
            with open(src_path, "r", encoding="utf-8") as src, open(dst_path, "a", encoding="utf-8") as dst:
                dst.write(src.read())
            return
        except PermissionError as e:
            last_err = e
            time.sleep(delay)
    raise last_err

def remove_file_if_exists(path: Path):
    try:
        os.remove(path)
    except OSError:
        pass

spines_dict = spine_dataset.spine_meshes

for batch_idx, batch_dict in enumerate(
    iter_batches_from_dict(spines_dict, batch_size=batch_size, start_batch=start_batch),
    start=start_batch
):
    try:
        remove_file_if_exists(tmp_metrics_path)
#         remove_file_if_exists(tmp_chords_path)

        spine_metrics = SpineMetricDataset()
        spine_metrics.calculate_metrics(batch_dict, metric_names, metric_params)

        spine_metrics.save(str(tmp_metrics_path))
#         spine_metrics.get_metrics_subset(["OldChordDistribution"]).save_as_array(str(tmp_chords_path))

        append_file(tmp_metrics_path, out_metrics_path, retries=10, delay=1.0)
#         append_file(tmp_chords_path, out_chords_path, retries=10, delay=1.0)

        print(f"✅ saved batch #{batch_idx} ({len(batch_dict)} items) -> {out_metrics_path}, {out_chords_path}")

    except PermissionError as e:
        print(f"❌ PermissionError on batch #{batch_idx}: {e}")
        print("Проверь, что metrics.csv / chords.csv закрыты (Excel и т.п.) и нет второго запущенного скрипта.")
        break

    except Exception as e:
        print(f"❌ error on batch #{batch_idx}: {e}")
        break

remove_file_if_exists(tmp_metrics_path)
# remove_file_if_exists(tmp_chords_path)

t1 = time.perf_counter()
print(f"Общее время выполнения: {t1 - t0:.3f} сек")
# Out:
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:05<00:00,  6.55s/it]
# ✅ saved batch #0 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:52<00:00,  5.24s/it]
# ✅ saved batch #1 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:32<00:00,  3.25s/it]
# ✅ saved batch #2 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:22<00:00,  2.23s/it]
# ✅ saved batch #3 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.05s/it]
# ✅ saved batch #4 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:56<00:00,  5.68s/it]
# ✅ saved batch #5 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:13<00:00,  7.38s/it]
# ✅ saved batch #6 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:02<00:00,  6.25s/it]
# ✅ saved batch #7 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:33<00:00,  3.36s/it]
# ✅ saved batch #8 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:41<00:00,  4.18s/it]
# ✅ saved batch #9 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:30<00:00,  9.00s/it]
# ✅ saved batch #10 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:10<00:00,  7.05s/it]
# ✅ saved batch #11 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:31<00:00,  3.12s/it]
# ✅ saved batch #12 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.05s/it]
# ✅ saved batch #13 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:36<00:00,  3.65s/it]
# ✅ saved batch #14 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:17<00:00,  7.71s/it]
# ✅ saved batch #15 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:42<00:00, 10.26s/it]
# ✅ saved batch #16 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:39<00:00,  3.90s/it]
# ✅ saved batch #17 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:19<00:00,  7.98s/it]
# ✅ saved batch #18 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:59<00:00,  5.95s/it]
# ✅ saved batch #19 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:43<00:00,  4.38s/it]
# ✅ saved batch #20 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:39<00:00,  3.95s/it]
# ✅ saved batch #21 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:31<00:00,  3.10s/it]
# ✅ saved batch #22 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:46<00:00,  4.70s/it]
# ✅ saved batch #23 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:13<00:00,  1.31s/it]
# ✅ saved batch #24 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:46<00:00,  4.63s/it]
# ✅ saved batch #25 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:59<00:00,  5.93s/it]
# ✅ saved batch #26 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:52<00:00, 11.29s/it]
# ✅ saved batch #27 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:43<00:00,  4.36s/it]
# ✅ saved batch #28 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:36<00:00,  3.61s/it]
# ✅ saved batch #29 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:57<00:00,  5.72s/it]
# ✅ saved batch #30 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:57<00:00,  5.76s/it]
# ✅ saved batch #31 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:22<00:00,  2.27s/it]
# ✅ saved batch #32 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.02s/it]
# ✅ saved batch #33 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.57s/it]
# ✅ saved batch #34 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:27<00:00,  8.77s/it]
# ✅ saved batch #35 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:39<00:00,  9.98s/it]
# ✅ saved batch #36 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.09s/it]
# ✅ saved batch #37 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:08<00:00,  6.89s/it]
# ✅ saved batch #38 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:21<00:00,  8.16s/it]
# ✅ saved batch #39 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:26<00:00,  8.63s/it]
# ✅ saved batch #40 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:27<00:00, 14.75s/it]
# ✅ saved batch #41 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.05s/it]
# ✅ saved batch #42 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:39<00:00, 16.00s/it]
# ✅ saved batch #43 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.10s/it]
# ✅ saved batch #44 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:59<00:00,  5.97s/it]
# ✅ saved batch #45 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:47<00:00,  4.74s/it]
# ✅ saved batch #46 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:10<00:00,  7.07s/it]
# ✅ saved batch #47 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:57<00:00,  5.79s/it]
# ✅ saved batch #48 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:27<00:00,  8.78s/it]
# ✅ saved batch #49 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.47s/it]
# ✅ saved batch #50 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:19<00:00,  1.98s/it]
# ✅ saved batch #51 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:56<00:00,  5.68s/it]
# ✅ saved batch #52 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:34<00:00,  9.45s/it]
# ✅ saved batch #53 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:01<00:00,  6.20s/it]
# ✅ saved batch #54 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:29<00:00,  8.99s/it]
# ✅ saved batch #55 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:44<00:00, 10.41s/it]
# ✅ saved batch #56 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:19<00:00,  7.90s/it]
# ✅ saved batch #57 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:23<00:00,  8.38s/it]
# ✅ saved batch #58 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:29<00:00,  2.95s/it]
# ✅ saved batch #59 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:06<00:00,  6.61s/it]
# ✅ saved batch #60 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:30<00:00,  3.03s/it]
# ✅ saved batch #61 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:53<00:00,  5.36s/it]
# ✅ saved batch #62 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:26<00:00,  8.65s/it]
# ✅ saved batch #63 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:29<00:00,  8.91s/it]
# ✅ saved batch #64 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:58<00:00,  5.89s/it]
# ✅ saved batch #65 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:54<00:00,  5.42s/it]
# ✅ saved batch #66 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:03<00:00, 12.37s/it]
# ✅ saved batch #67 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:34<00:00,  9.47s/it]
# ✅ saved batch #68 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.07s/it]
# ✅ saved batch #69 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:05<00:00,  6.54s/it]
# ✅ saved batch #70 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:35<00:00,  9.57s/it]
# ✅ saved batch #71 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:43<00:00, 10.36s/it]
# ✅ saved batch #72 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:59<00:00,  5.99s/it]
# ✅ saved batch #73 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:58<00:00, 11.88s/it]
# ✅ saved batch #74 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:15<00:00,  7.59s/it]
# ✅ saved batch #75 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:32<00:00, 15.23s/it]
# ✅ saved batch #76 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:35<00:00,  9.51s/it]
# ✅ saved batch #77 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:39<00:00,  3.98s/it]
# ✅ saved batch #78 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:57<00:00,  5.76s/it]
# ✅ saved batch #79 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:14<00:00, 13.44s/it]
# ✅ saved batch #80 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:47<00:00,  4.73s/it]
# ✅ saved batch #81 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:45<00:00,  4.54s/it]
# ✅ saved batch #82 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:28<00:00,  2.84s/it]
# ✅ saved batch #83 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:06<00:00,  6.68s/it]
# ✅ saved batch #84 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:36<00:00,  3.60s/it]
# ✅ saved batch #85 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:48<00:00,  4.82s/it]
# ✅ saved batch #86 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:18<00:00,  1.86s/it]
# ✅ saved batch #87 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:31<00:00,  3.19s/it]
# ✅ saved batch #88 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:25<00:00,  8.51s/it]
# ✅ saved batch #89 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:56<00:00,  5.65s/it]
# ✅ saved batch #90 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:25<00:00,  2.59s/it]
# ✅ saved batch #91 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:50<00:00, 11.04s/it]
# ✅ saved batch #92 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:40<00:00,  4.04s/it]
# ✅ saved batch #93 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:16<00:00, 13.67s/it]
# ✅ saved batch #94 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [01:12<00:00,  7.23s/it]
# ✅ saved batch #95 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:20<00:00,  2.04s/it]
# ✅ saved batch #96 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:44<00:00,  4.48s/it]
# ✅ saved batch #97 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:21<00:00, 14.16s/it]
# ✅ saved batch #98 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:44<00:00,  4.45s/it]
# ✅ saved batch #99 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:22<00:00,  2.30s/it]
# ✅ saved batch #100 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:34<00:00,  3.42s/it]
# ✅ saved batch #101 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:57<00:00,  5.73s/it]
# ✅ saved batch #102 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:41<00:00,  4.15s/it]
# ✅ saved batch #103 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [00:50<00:00,  5.02s/it]
# ✅ saved batch #104 (10 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# processes  8
# run pool with 8 processes num
# 100%|████████████████████████████████████████████████████████████████████████████████████| 4/4 [00:29<00:00,  7.38s/it]
# ✅ saved batch #105 (4 items) -> Mouse_basal\z-corr\metrics.csv, Mouse_basal\z-corr\chords.csv
# Общее время выполнения: 6695.878 сек

# %%
from spine_analysis.shape_metric.io_metric import SpineMetricDataset
import time
import itertools
import os
from pathlib import Path

t0 = time.perf_counter()

# chord method parameters
num_of_chords = 30000
num_of_bins = 100

# calculate metrics
# metric_names = ["OldChordDistribution", "OpenAngle", "CVD", "AverageDistance",
#                 "LengthVolumeRatio", "LengthAreaRatio", "JunctionArea",
#                 "Length", "Area", "Volume", "ConvexHullVolume", "ConvexHullRatio",
#                 "LightFieldZernikeMoments", "SphericalGarmonics"]

# metric_names = ["OldChordDistribution", "OpenAngle", "CVD", "AverageDistance",
#                 "LengthVolumeRatio", "LengthAreaRatio", "JunctionArea",
#                 "Length", "Area", "Volume", "ConvexHullVolume", "ConvexHullRatio"]

# metric_names = ["LightFieldZernikeMoments", "SphericalGarmonics"]
metric_names = ["SphericalGarmonics"]
# metric_names = ["LightFieldZernikeMoments"]

# metric_params = [{"num_of_chords": num_of_chords, "num_of_bins": num_of_bins},
#                  {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}, {}]
metric_params = [{}, {}]

# spine_metrics = SpineMetricDataset()
# spine_metrics.calculate_metrics(spine_dataset.spine_meshes, metric_names, metric_params)
# spine_metrics.save(f"{dataset_path}/metrics.csv")    

# spine_metrics.get_metrics_subset(["OldChordDistribution"]).save_as_array(f"{dataset_path}/chords.csv")
# spine_metrics.get_metrics_subset(["LightFieldZernikeMoments"]).save_as_array(f"{dataset_path}/lf_descriptor.csv")
# spine_metrics.get_metrics_subset(["SphericalGarmonics"]).save_as_array(f"{dataset_path}/spherical_garmonics.csv")

out_path = Path(dataset_path) / "spherical_garmonics.csv"
# out_path = Path(dataset_path) / "light_field_zernike_moments.csv"
tmp_path = out_path.with_suffix(".tmp.csv")

batch_size = 10
start_batch = 0

out_path.parent.mkdir(parents=True, exist_ok=True)

def iter_batches_from_dict(d: dict, batch_size: int, start_batch: int = 0):
    start_item = start_batch * batch_size
    it = itertools.islice(d.items(), start_item, None)  
    while True:
        chunk = list(itertools.islice(it, batch_size))
        if not chunk:
            break
        yield dict(chunk)

def append_file(src_path: Path, dst_path: Path, retries: int = 5, delay: float = 1.0):
    last_err = None
    for attempt in range(retries):
        try:
            with open(src_path, "r", encoding="utf-8") as src, open(dst_path, "a", encoding="utf-8") as dst:
                dst.write(src.read())
            return
        except PermissionError as e:
            last_err = e
            time.sleep(delay)
    raise last_err

spines_dict = spine_dataset.spine_meshes  

for batch_idx, batch_dict in enumerate(
    iter_batches_from_dict(spines_dict, batch_size=batch_size, start_batch=start_batch),
    start=start_batch
):
    try:
        spine_metrics = SpineMetricDataset()
        spine_metrics.calculate_metrics(batch_dict, metric_names, metric_params)

        spine_metrics.get_metrics_subset(["SphericalGarmonics"]).save_as_array(str(tmp_path))
#         spine_metrics.get_metrics_subset(["LightFieldZernikeMoments"]).save_as_array(str(tmp_path))

        append_file(tmp_path, out_path, retries=10, delay=1.0)

        print(f"✅ saved batch #{batch_idx} ({len(batch_dict)} items) -> {out_path}")

    except PermissionError as e:
        print(f"❌ PermissionError on batch #{batch_idx}: {e}")
        print("Проверь, что spherical_garmonics.csv закрыт (Excel и т.п.) и нет второго запущенного скрипта.")
        break

    except Exception as e:
        print(f"❌ error on batch #{batch_idx}: {e}")
        break

try:
    os.remove(tmp_path)
except OSError:
    pass

t1 = time.perf_counter()

print(f"Общее время выполнения: {t1 - t0:.3f} сек")
# Out:
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:48<00:00, 34.83s/it]
# ✅ saved batch #0 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:54<00:00, 35.40s/it]
# ✅ saved batch #1 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:57<00:00, 29.77s/it]
# ✅ saved batch #2 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:17<00:00, 31.72s/it]
# ✅ saved batch #3 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:50<00:00, 41.07s/it]
# ✅ saved batch #4 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:22<00:00, 32.24s/it]
# ✅ saved batch #5 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:41<00:00, 28.16s/it]
# ✅ saved batch #6 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:32<00:00, 33.21s/it]
# ✅ saved batch #7 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:52<00:00, 23.23s/it]
# ✅ saved batch #8 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:07<00:00, 36.76s/it]
# ✅ saved batch #9 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [08:04<00:00, 48.45s/it]
# ✅ saved batch #10 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:39<00:00, 33.91s/it]
# ✅ saved batch #11 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:17<00:00, 31.72s/it]
# ✅ saved batch #12 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:00<00:00, 36.08s/it]
# ✅ saved batch #13 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:06<00:00, 30.66s/it]
# ✅ saved batch #14 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:39<00:00, 45.91s/it]
# ✅ saved batch #15 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:39<00:00, 40.00s/it]
# ✅ saved batch #16 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:37<00:00, 39.77s/it]
# ✅ saved batch #17 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:19<00:00, 31.95s/it]
# ✅ saved batch #18 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:57<00:00, 29.71s/it]
# ✅ saved batch #19 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:27<00:00, 38.78s/it]
# ✅ saved batch #20 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:27<00:00, 32.76s/it]
# ✅ saved batch #21 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:32<00:00, 33.22s/it]
# ✅ saved batch #22 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:47<00:00, 34.77s/it]
# ✅ saved batch #23 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:11<00:00, 31.19s/it]
# ✅ saved batch #24 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:26<00:00, 26.60s/it]
# ✅ saved batch #25 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:24<00:00, 38.41s/it]
# ✅ saved batch #26 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:32<00:00, 27.24s/it]
# ✅ saved batch #27 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [09:24<00:00, 56.49s/it]
# ✅ saved batch #28 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:20<00:00, 38.07s/it]
# ✅ saved batch #29 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:14<00:00, 25.45s/it]
# ✅ saved batch #30 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:46<00:00, 28.70s/it]
# ✅ saved batch #31 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:12<00:00, 31.24s/it]
# ✅ saved batch #32 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:42<00:00, 28.25s/it]
# ✅ saved batch #33 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:56<00:00, 23.64s/it]
# ✅ saved batch #34 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:34<00:00, 33.44s/it]
# ✅ saved batch #35 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:27<00:00, 26.80s/it]
# ✅ saved batch #36 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:38<00:00, 27.87s/it]
# ✅ saved batch #37 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:10<00:00, 31.01s/it]
# ✅ saved batch #38 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:43<00:00, 40.38s/it]
# ✅ saved batch #39 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:15<00:00, 31.57s/it]
# ✅ saved batch #40 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:48<00:00, 28.82s/it]
# ✅ saved batch #41 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:59<00:00, 47.91s/it]
# ✅ saved batch #42 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:45<00:00, 28.51s/it]
# ✅ saved batch #43 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:54<00:00, 35.40s/it]
# ✅ saved batch #44 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:27<00:00, 38.73s/it]
# ✅ saved batch #45 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:39<00:00, 39.97s/it]
# ✅ saved batch #46 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:33<00:00, 45.31s/it]
# ✅ saved batch #47 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:55<00:00, 41.58s/it]
# ✅ saved batch #48 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:17<00:00, 43.80s/it]
# ✅ saved batch #49 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:05<00:00, 36.58s/it]
# ✅ saved batch #50 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:34<00:00, 39.43s/it]
# ✅ saved batch #51 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:50<00:00, 35.07s/it]
# ✅ saved batch #52 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:39<00:00, 39.94s/it]
# ✅ saved batch #53 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:05<00:00, 36.52s/it]
# ✅ saved batch #54 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:22<00:00, 32.20s/it]
# ✅ saved batch #55 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:18<00:00, 37.84s/it]
# ✅ saved batch #56 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [08:43<00:00, 52.35s/it]
# ✅ saved batch #57 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:52<00:00, 41.22s/it]
# ✅ saved batch #58 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:49<00:00, 34.92s/it]
# ✅ saved batch #59 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:33<00:00, 33.34s/it]
# ✅ saved batch #60 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:39<00:00, 39.91s/it]
# ✅ saved batch #61 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:46<00:00, 28.63s/it]
# ✅ saved batch #62 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:37<00:00, 33.73s/it]
# ✅ saved batch #63 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:15<00:00, 31.54s/it]
# ✅ saved batch #64 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:33<00:00, 33.38s/it]
# ✅ saved batch #65 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:42<00:00, 28.22s/it]
# ✅ saved batch #66 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:41<00:00, 34.16s/it]
# ✅ saved batch #67 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:12<00:00, 31.24s/it]
# ✅ saved batch #68 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:56<00:00, 35.61s/it]
# ✅ saved batch #69 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:42<00:00, 40.22s/it]
# ✅ saved batch #70 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:47<00:00, 34.75s/it]
# ✅ saved batch #71 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:02<00:00, 42.25s/it]
# ✅ saved batch #72 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [02:56<00:00, 17.64s/it]
# ✅ saved batch #73 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:33<00:00, 27.37s/it]
# ✅ saved batch #74 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:21<00:00, 44.19s/it]
# ✅ saved batch #75 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:42<00:00, 46.26s/it]
# ✅ saved batch #76 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:43<00:00, 46.30s/it]
# ✅ saved batch #77 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:36<00:00, 33.66s/it]
# ✅ saved batch #78 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:29<00:00, 44.97s/it]
# ✅ saved batch #79 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:46<00:00, 34.65s/it]
# ✅ saved batch #80 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:41<00:00, 34.17s/it]
# ✅ saved batch #81 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:33<00:00, 33.38s/it]
# ✅ saved batch #82 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:12<00:00, 31.29s/it]
# ✅ saved batch #83 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:14<00:00, 43.48s/it]
# ✅ saved batch #84 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:00<00:00, 36.02s/it]
# ✅ saved batch #85 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [08:30<00:00, 51.08s/it]
# ✅ saved batch #86 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:14<00:00, 31.48s/it]
# ✅ saved batch #87 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:02<00:00, 36.25s/it]
# ✅ saved batch #88 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:45<00:00, 46.58s/it]
# ✅ saved batch #89 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:27<00:00, 26.79s/it]
# ✅ saved batch #90 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [10:29<00:00, 62.92s/it]
# ✅ saved batch #91 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:30<00:00, 39.04s/it]
# ✅ saved batch #92 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:41<00:00, 34.17s/it]
# ✅ saved batch #93 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:04<00:00, 36.48s/it]
# ✅ saved batch #94 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:36<00:00, 33.63s/it]
# ✅ saved batch #95 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:16<00:00, 37.65s/it]
# ✅ saved batch #96 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:08<00:00, 36.86s/it]
# ✅ saved batch #97 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:15<00:00, 31.56s/it]
# ✅ saved batch #98 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:24<00:00, 32.48s/it]
# ✅ saved batch #99 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:23<00:00, 38.32s/it]
# ✅ saved batch #100 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:20<00:00, 26.06s/it]
# ✅ saved batch #101 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:26<00:00, 26.63s/it]
# ✅ saved batch #102 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:12<00:00, 19.29s/it]
# ✅ saved batch #103 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:47<00:00, 22.77s/it]
# ✅ saved batch #104 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:36<00:00, 27.64s/it]
# ✅ saved batch #105 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:53<00:00, 23.38s/it]
# ✅ saved batch #106 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:35<00:00, 21.53s/it]
# ✅ saved batch #107 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:49<00:00, 28.99s/it]
# ✅ saved batch #108 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:52<00:00, 35.29s/it]
# ✅ saved batch #109 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:46<00:00, 40.69s/it]
# ✅ saved batch #110 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:54<00:00, 29.41s/it]
# ✅ saved batch #111 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:16<00:00, 25.63s/it]
# ✅ saved batch #112 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [04:59<00:00, 29.92s/it]
# ✅ saved batch #113 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:56<00:00, 41.66s/it]
# ✅ saved batch #114 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [03:33<00:00, 21.38s/it]
# ✅ saved batch #115 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:57<00:00, 35.73s/it]
# ✅ saved batch #116 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:25<00:00, 32.59s/it]
# ✅ saved batch #117 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:17<00:00, 31.75s/it]
# ✅ saved batch #118 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:20<00:00, 38.10s/it]
# ✅ saved batch #119 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:01<00:00, 42.19s/it]
# ✅ saved batch #120 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:06<00:00, 42.67s/it]
# ✅ saved batch #121 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:02<00:00, 30.29s/it]
# ✅ saved batch #122 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [09:08<00:00, 54.81s/it]
# ✅ saved batch #123 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:51<00:00, 47.14s/it]
# ✅ saved batch #124 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [09:39<00:00, 57.97s/it]
# ✅ saved batch #125 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [10:00<00:00, 60.06s/it]
# ✅ saved batch #126 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:06<00:00, 42.66s/it]
# ✅ saved batch #127 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [08:24<00:00, 50.42s/it]
# ✅ saved batch #128 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [06:50<00:00, 41.03s/it]
# ✅ saved batch #129 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [07:18<00:00, 43.84s/it]
# ✅ saved batch #130 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
# 100%|██████████████████████████████████████████████████████████████████████████████████| 10/10 [05:11<00:00, 31.18s/it]
# ✅ saved batch #131 (10 items) -> Human_age_85_basal_OFF\z-corr\spherical_garmonics.csv
# processes  8
# run pool with 8 processes num
#   0%|                                                                                           | 0/10 [00:00<?, ?it/s]

# %%
import csv
import numpy as np
from spine_analysis.shape_metric.approximation_metric import SphericalGarmonicsSpineMetric

def read_first_nonempty_rows(csv_path, n=2):
    rows = []
    with open(csv_path, "r", encoding="utf-8") as f:
        reader = csv.reader(f)
        for row in reader:
            if len(row) <= 1:
                continue
            rows.append((row[0], np.array([float(x) for x in row[1:]], dtype=float)))
            if len(rows) == n:
                break
    return rows

rows = read_first_nonempty_rows("Mouse_basal/z-corr/spherical_garmonics.csv", n=10)

for name, coeffs in rows:
    print(name)
    metric = SphericalGarmonicsSpineMetric()
    metric.value = coeffs
    widget = metric.show()   
    display(widget)
# Out:
# Mouse_basal/z-corr/spine_1004.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.024830…
# Mouse_basal/z-corr/spine_1001.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0378786…
# Mouse_basal/z-corr/spine_100.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(0.0197612…
# Mouse_basal/z-corr/spine_1002.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.072287…
# Mouse_basal/z-corr/spine_1000.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.009409…
# Mouse_basal/z-corr/spine_1.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.010206…
# Mouse_basal/z-corr/spine_0.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.037313…
# Mouse_basal/z-corr/spine_1003.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.074028…
# Mouse_basal/z-corr/spine_1006.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.002243…
# Mouse_basal/z-corr/spine_10.off
# Renderer(camera=PerspectiveCamera(children=(DirectionalLight(color='white', intensity=0.6, position=(-0.032801…

# %% [markdown]
# ### View Spines in Dataset

# %%
from spine_analysis.shape_metric.io_metric import SpineMetricDataset
from notebook_widgets import spine_dataset_view_widget


metrics = SpineMetricDataset().load(f"{dataset_path}/metrics.csv")
display(spine_dataset_view_widget(scaled_spine_dataset, metrics))

# %% [markdown]
# ### Merge Manual Classifications

# %%
from spine_analysis.shape_metric.io_metric import SpineMetricDataset
from spine_analysis.spine.grouping import SpineGrouping
from notebook_widgets import create_dir, remove_file
import pathlib

dataset_path = "0.025 0.025 0.1 dataset"
merged_path = f"{dataset_path}/manual_classification/manual_classification_merged.json"
merged_reduced_path = f"{dataset_path}/manual_classification/manual_classification_merged_reduced.json"

# remove old merged classifications
remove_file(merged_path)
remove_file(merged_reduced_path)

# load manual classifications
path = pathlib.Path(f"{dataset_path}/manual_classification")
classifications_paths = path.glob("*.json")
groupings = [SpineGrouping().load(str(path)) for path in classifications_paths]
classification_paths = [str(classification_path) for classification_path in path.glob("*.json")]
groupings = [SpineGrouping().load(path) for path in classification_paths]
print(f"Merging manual classifications: {classification_paths}\n")

# merge classifications
merged_grouping = SpineGrouping.merge(groupings, outliers_label="Unclassified")
merged_grouping.save(merged_path)
print(f"Saved to \"{merged_path}\".")

# remove spines with no consensus, filopodias and labeled-as-outliers
contested = SpineGrouping.get_contested_samples(groupings)
merged_grouping.remove_samples(contested)
merged_grouping.remove_samples(merged_grouping.groups["Filopodia"].copy())
merged_grouping.remove_samples(merged_grouping.groups["Outlier"].copy())
del merged_grouping.groups["Filopodia"]
del merged_grouping.groups["Outlier"]

merged_grouping.save(merged_reduced_path)
print(f"Saved to \"{merged_reduced_path}\".")

# %% [markdown]
# ### Consensus Table

# %%
from notebook_widgets import consensus_widget
from spine_analysis.spine.grouping import SpineGrouping
import pathlib

# load manual classifications
path = pathlib.Path(f"{dataset_path}/manual_classification")
classifications_paths = path.glob("*.json")
groupings = [SpineGrouping().load(str(path)) for path in classifications_paths]
classification_paths = path.glob("manual_classification_?.json")
groupings = [SpineGrouping().load(str(path)) for path in classification_paths]

# show consensus table
display(consensus_widget(groupings))

# %% [markdown]
# ### Merge Train & Test Manual Classifications

# %%
from spine_fitter import SpineGrouping
import pathlib


def remove_prefix(grouping: SpineGrouping, prefix: str) -> None:
    for label, group in grouping.groups.items():
        new_group = set()
        for spine_name in group:
            new_group.add(spine_name.replace(prefix, ""))
        grouping.groups[label] = new_group

    new_samples = set()    
    for spine_name in grouping.samples:
        new_samples.add(spine_name.replace(prefix, ""))
    grouping.samples = new_samples


path = pathlib.Path(f"test 0.025 0.025 0.1 dataset/manual_classification")
classification_paths = path.glob("manual_classification_?.json")

for classification_path in classification_paths:
    grouping_test = SpineGrouping().load(str(classification_path))
    grouping_train = SpineGrouping().load(f"train 0.025 0.025 0.1 dataset/manual_classification/{classification_path.name}")

    remove_prefix(grouping_train, "train ")
    remove_prefix(grouping_test, "test ")

    merged = SpineGrouping.merge([grouping_train, grouping_test])
    merged.save(f"0.025 0.025 0.1 dataset/manual_classification/{classification_path.name}")
    
    print(f'Saved classification to "0.025 0.025 0.1 dataset/manual_classification/{classification_path.name}"')

# %% [markdown]
# ### Clusters diagrams

# %%
from spine_analysis.spine.grouping import SpineGrouping
import matplotlib.pyplot as plt
import pathlib
import glob

def get_distribution(classes, clusters, ax, *replasing_args) -> None:
  col = ['g','r', 'y', 'b', 'm', 'c', 'k', 'orange', 'lightgreen', 'pink', 'yellow']
  colors = {k: col[i] for i, k in enumerate(classes.group_labels)}
  #colors = {'Stubby': 'y', 'Mushroom': 'g', 'Thin': 'r'}
  print(colors)
  
  for j, lab in enumerate(clusters.group_labels):
    ss = {spike.replace(*replasing_args) for spike in clusters.groups[lab]}
    cluster_j_distribution = classes.get_spines_subset(ss.intersection([spike.replace(*replasing_args) for spikes in classes.groups.values() for spike in spikes]))
    
    labels = list(cluster_j_distribution.group_labels)
    sizes = [len(cluster_j_distribution.groups[man_lab]) for man_lab in labels]

    drawed_labels = [labels[k] for k,s in enumerate(sizes) if s > 0]
    drawed_sizes = [s for s in sizes if s > 0]
    ax[j].pie(drawed_sizes, colors = [colors[lab] for lab in drawed_labels], autopct='',
        shadow=True, startangle=90)


dataset_path = '0.025-0.025-0.1-dataset'

manual_path = pathlib.Path(f"output/clusterization/0.025-0.025-0.1-dataset_chord_kmeans_num_of_clusters=5_pca=2_5_clusters.json")
#manual_path = pathlib.Path(f"{dataset_path}/manual_classification/manual_classification_merged_reduced.json")
classifications_paths = glob.glob("output/clusterization/zernike_abs_kernel_kmeans_num_of_clusters*.json")
groupings = [SpineGrouping().load(str(path)) for path in classifications_paths]
groupings = [groupings[4], groupings[0], groupings[-1], groupings[-3], groupings[3], groupings[2], groupings[-2], groupings[1]]
manual_grouping = SpineGrouping().load(manual_path)

fig, ax = plt.subplots(ncols=max(len(g.group_labels) for g in groupings), nrows = len(groupings), figsize=(10, 15))

for i, g in enumerate(groupings):
  get_distribution(manual_grouping, g, ax[i], '/', '\\')
plt.show()

# %%
fig, ax = plt.subplots(ncols=len(manual_grouping.group_labels), nrows = len(groupings), figsize=(5, 15))

for j, lab in enumerate(manual_grouping.group_labels):
  ax[0, j].set_title(lab)
for i, g in enumerate(groupings):
  get_distribution(g, manual_grouping, ax[i], '\\', '/')
plt.show()

# %% [markdown]
# ### cluster visualization

# %%
from spine_analysis.shape_metric.io_metric import SpineMetricDataset
from notebook_widgets import SpineMeshDataset, clasters_spines_widget, make_viewer, widgets
from spine_segmentation import apply_scale
from spine_analysis.spine.grouping import SpineGrouping

clusterization_save_path = 'output/clusterization/zernike_real_12_kernel_kmeans_num_of_clusters=6_pca=-1_5_clusters.json'
meshes_path = '0.025 0.025 0.1 dataset'

spine_dataset = SpineMeshDataset().load(meshes_path)
spine_dataset.apply_scale((1, 1, 0.1))

clusterization = SpineGrouping()
clusterization.load(clusterization_save_path)

display(clasters_spines_widget(spine_dataset, clusterization))

# %% [markdown]
# ### Get LF distances matrix and inspect closest/farthest spines

# %%
import numpy as np

from spine_analysis.shape_metric.approximation_metric import LightFieldZernikeMomentsSpineMetric
from notebook_widgets import SpineMeshDataset

meshes_path = '0.025 0.025 0.1 dataset'

spine_dataset = SpineMeshDataset().load(meshes_path)
lf_name = 'LightFieldZernikeMoments'

spine_metrics_lf = SpineMetricDataset()
spine_metrics_lf.calculate_metrics(spine_dataset.spine_meshes, [lf_name])
spine_metrics_lf_real = spine_metrics_lf.get_metrics_subset([lf_name])
spine_metrics_lf_real.clasterization_preprocess(zernike_postprocess='real')

meshes_names = list(spine_dataset.spine_names)
distanses = np.identity((len(meshes_names)))
distanses *= -1
for i, name_1 in enumerate(meshes_names):
  for j, name_2 in enumerate(meshes_names):
    if i == j:
      continue
    distanses[i,j] = LightFieldZernikeMomentsSpineMetric.distance(spine_metrics_lf_real.element(name_1, lf_name), spine_metrics_lf_real.element(name_2, lf_name))

# farthest spines
index = distanses.argmax()
i = index // len(meshes_names)
j = index % len(meshes_names)
print(distanses.max(), meshes_names[i], meshes_names[j])

#closest spines
distanses[distanses < 0] = 10e14
index = distanses.argmin()
i = index // len(meshes_names)
j = index % len(meshes_names)
print(distanses.min(), meshes_names[i], meshes_names[j])
